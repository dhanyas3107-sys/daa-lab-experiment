# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanyas3107-sys/daa-lab-experiment/blob/main/4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq


def dijkstra_hops(graph, source):

    n = len(graph)

    dist = [float('inf')] * n
    hops = [float('inf')] * n

    prev = [None] * n

    dist[source] = 0
    hops[source] = 0

    pq = [(0, 0, source)]
    visited = set()

    while pq:

        d, h, u = heapq.heappop(pq)

        if u in visited:
            continue

        visited.add(u)

        for v, w in graph[u]:

            new_dist = dist[u] + w
            new_hops = hops[u] + 1

            if new_dist < dist[v]:

                dist[v] = new_dist
                hops[v] = new_hops
                prev[v] = u

                heapq.heappush(
                    pq,
                    (dist[v], hops[v], v)
                )

            elif new_dist == dist[v]:

                if new_hops < hops[v]:

                    hops[v] = new_hops
                    prev[v] = u

                    heapq.heappush(
                        pq,
                        (dist[v], hops[v], v)
                    )

    return dist, hops, prev


def reconstruct_path(prev, source, target):

    path = []

    node = target

    while node is not None:
        path.append(node)
        node = prev[node]

    path.reverse()

    if path[0] == source:
        return path

    return []


# -----------------------
# Test Graph (6 vertices)
# -----------------------

graph = {
    0: [(1, 2), (2, 1)],
    1: [(5, 4)],
    2: [(3, 1)],
    3: [(4, 1)],
    4: [(5, 3)],
    5: []
}

source = 0

dist, hops, prev = dijkstra_hops(graph, source)

print(f'{"Vertex":>8} {"Distance":>10} {"Hops":>10} {"Path":>25}')
print("-" * 60)

for v in range(len(graph)):

    path = reconstruct_path(prev, source, v)

    path_str = (
        " -> ".join(map(str, path))
        if path else "No Path"
    )

    print(
        f'{v:>8} '
        f'{dist[v]:>10} '
        f'{hops[v]:>10} '
        f'{path_str:>25}'
    )
# Out:
#   Vertex   Distance       Hops                      Path
# ------------------------------------------------------------
#        0          0          0                         0
#        1          2          1                    0 -> 1
#        2          1          1                    0 -> 2
#        3          2          2               0 -> 2 -> 3
#        4          3          3          0 -> 2 -> 3 -> 4
#        5          6          2               0 -> 1 -> 5
